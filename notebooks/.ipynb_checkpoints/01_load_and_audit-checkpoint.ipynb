# %%
# Part C — Load and Data Audit

""This notebook loads the selected datasets and performs basic data audits,
including dataset size, unique patient counts, and missingness analysis.""

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
radiology = pd.read_excel(
    "../data/raw/tcga-ov/TCIA_TCGA-OV_09-16-2015-nbia-digest.xlsx"
)

# %%
radiology.head()
# Out:
#      Patient ID  Patient Name  Patient Birth Date Patient Sex Ethnic Group  \
# 0  TCGA-24-0966  TCGA-24-0966                 NaN           F          NaN
# 1  TCGA-24-0966  TCGA-24-0966                 NaN           F          NaN
# 2  TCGA-24-0966  TCGA-24-0966                 NaN           F          NaN
# 3  TCGA-24-0966  TCGA-24-0966                 NaN           F          NaN
# 4  TCGA-24-0966  TCGA-24-0966                 NaN           F          NaN
#
#   Phantom  Species Code Species Description  \
# 0      NO     337915000        Homo sapiens
# 1      NO     337915000        Homo sapiens
# 2      NO     337915000        Homo sapiens
# 3      NO     337915000        Homo sapiens
# 4      NO     337915000        Homo sapiens
#
#                                   Study Instance UID             Study Date  \
# 0  1.3.6.1.4.1.14519.5.2.1.7777.4007.330693106714...  1992-05-01 00:00:00.0
# 1  1.3.6.1.4.1.14519.5.2.1.7777.4007.330693106714...  1992-05-01 00:00:00.0
# ...

# %%
radiology.shape
# Out:
# (844, 36)

# %%
radiology.columns
# Out:
# Index(['Patient ID', 'Patient Name', 'Patient Birth Date', 'Patient Sex',
#        'Ethnic Group', 'Phantom', 'Species Code', 'Species Description',
#        'Study Instance UID', 'Study Date', 'Study Description',
#        'Admitting Diagnosis Description', 'Study ID', 'Patient Age',
#        'Longitudinal Temporal Event Type',
#        'Longitudinal Temporal Offset From Event', 'Series Instance UID',
#        'Project', 'Modality', 'Protocol Name', 'Series Date',
#        'Series Description', 'Body Part Examined', 'Series Number',
#        'Annotations Flag', 'Manufacturer', 'Manufacturer Model Name',
#        'Software Versions', 'Image Count', 'Max Submission Timestamp',
#        'License Name', 'License URI', 'Collection URI', 'File Size',
#        'Date Released', 'Third Party Analysis'],
#       dtype='object')

# %%
radiology['Patient ID'].nunique()
# Out:
# 143

# %%
# Missingness (% missing per column) — Radiology
radiology.isna().mean().mul(100).sort_values()
# Out:
# Patient ID                                   0.000000
# File Size                                    0.000000
# Collection URI                               0.000000
# License URI                                  0.000000
# License Name                                 0.000000
# Max Submission Timestamp                     0.000000
# Image Count                                  0.000000
# Body Part Examined                           0.000000
# Modality                                     0.000000
# Date Released                                0.000000
# Series Instance UID                          0.000000
# Project                                      0.000000
# Patient Name                                 0.000000
# Species Code                                 0.000000
# Study Date                                   0.000000
# Study Instance UID                           0.000000
# Phantom                                      0.000000
# ...

# %%
proteogenomics = pd.read_excel(
    "../data/raw/tcga_ov_proteogenomics/2020-02-26_Images_from_HGSOC_proteomics-nbia-digest.xlsx"
)

# %%
proteogenomics.head()
# Out:
#      Patient ID  Patient Name  Patient Birth Date Patient Sex  Ethnic Group  \
# 0  TCGA-24-1103  TCGA-24-1103                 NaN           F           NaN
# 1  TCGA-24-1103  TCGA-24-1103                 NaN           F           NaN
# 2  TCGA-24-1103  TCGA-24-1103                 NaN           F           NaN
# 3  TCGA-24-1103  TCGA-24-1103                 NaN           F           NaN
# 4  TCGA-24-1103  TCGA-24-1103                 NaN           F           NaN
#
#   Phantom  Species Code Species Description  \
# 0      NO     337915000        Homo sapiens
# 1      NO     337915000        Homo sapiens
# 2      NO     337915000        Homo sapiens
# 3      NO     337915000        Homo sapiens
# 4      NO     337915000        Homo sapiens
#
#                                   Study Instance UID             Study Date  \
# 0  1.3.6.1.4.1.14519.5.2.1.7777.4007.287113235960...  1985-11-06 00:00:00.0
# 1  1.3.6.1.4.1.14519.5.2.1.7777.4007.287113235960...  1985-11-06 00:00:00.0
# ...

# %%
proteogenomics.shape
# Out:
# (87, 36)

# %%
proteogenomics.columns
# Out:
# Index(['Patient ID', 'Patient Name', 'Patient Birth Date', 'Patient Sex',
#        'Ethnic Group', 'Phantom', 'Species Code', 'Species Description',
#        'Study Instance UID', 'Study Date', 'Study Description',
#        'Admitting Diagnosis Description', 'Study ID', 'Patient Age',
#        'Longitudinal Temporal Event Type',
#        'Longitudinal Temporal Offset From Event', 'Series Instance UID',
#        'Project', 'Modality', 'Protocol Name', 'Series Date',
#        'Series Description', 'Body Part Examined', 'Series Number',
#        'Annotations Flag', 'Manufacturer', 'Manufacturer Model Name',
#        'Software Versions', 'Image Count', 'Max Submission Timestamp',
#        'License Name', 'License URI', 'Collection URI', 'File Size',
#        'Date Released', 'Third Party Analysis'],
#       dtype='object')

# %%
proteogenomics['Patient ID'].nunique()
# Out:
# 20

# %%
proteogenomics.isna().mean().mul(100).sort_values()
# Out:
# Patient ID                                   0.000000
# File Size                                    0.000000
# Collection URI                               0.000000
# License URI                                  0.000000
# License Name                                 0.000000
# Max Submission Timestamp                     0.000000
# Image Count                                  0.000000
# Manufacturer Model Name                      0.000000
# Manufacturer                                 0.000000
# Series Number                                0.000000
# Body Part Examined                           0.000000
# Series Date                                  0.000000
# Modality                                     0.000000
# Date Released                                0.000000
# Series Instance UID                          0.000000
# Project                                      0.000000
# Study Instance UID                           0.000000
# ...
